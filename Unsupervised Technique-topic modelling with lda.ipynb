# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
import re
from gensim import corpora
from gensim.models import LdaModel
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim.models import Phrases
from gensim.models.phrases import Phraser
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# [nltk_data] Downloading package punkt to /Users/rohini/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rohini/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/rohini/nltk_data...
# True

# %%
data=pd.read_csv(r'job_description.csv')

# %%
data=data.drop(columns=['Unnamed: 0','Benefits','Requirement','Requirements'],axis=1)

# %%
data
# Out:
#              Category                                        Description
# 0    Business Analyst  Description\nJob Title: Junior Business Analys...
# 1    Business Analyst  Description\nThe Business Analyst (BA) will ca...
# 2    Business Analyst  Description\nWe help our clients design and de...
# 3    Business Analyst  Description\nFounded in 2015 and rapidly expan...
# 4    Business Analyst  Description\nWe are seeking a skilled Business...
# ..                ...                                                ...
# 320             UI/UX  Description\nThe UX Designer will be focused o...
# 321             UI/UX  Description\nWe are seeking a dynamic UI/UX de...
# 322             UI/UX  Description\nWe are looking for a UI/UX Design...
# 323             UI/UX  Description\nRemote – Full-Time\nClay is a glo...
# 324             UI/UX  Description\nRemote – Full-Time\nClay is a glo...
#
# [325 rows x 2 columns]

# %%
data['Category'].unique()
# Out:
# array(['Business Analyst', 'Cloud', 'Data Scientist', 'HR',
#        'Software Developer', 'UI/UX'], dtype=object)

# %%
# Get unique values in the "Category" column
unique_categories = data['Category'].unique()

# Create a dictionary to store datasets for each category
category_datasets = {}

# Iterate over unique categories
for category in unique_categories:
    # Select rows with the current category
    category_df = data[data['Category'] == category]
    # Create a new DataFrame containing both "Category" and "Description" columns
    category_description_df = category_df[['Category', 'Description']]
    # Store the DataFrame in the dictionary
    category_datasets[category] = category_description_df

# Print the first few rows of each dataset
for category, dataset in category_datasets.items():
    print(f"{category}:")
    print(dataset)  # Print the first three rows of each dataset
    print("----")
# Out:
# Business Analyst:
#             Category                                        Description
# 0   Business Analyst  Description\nJob Title: Junior Business Analys...
# 1   Business Analyst  Description\nThe Business Analyst (BA) will ca...
# 2   Business Analyst  Description\nWe help our clients design and de...
# 3   Business Analyst  Description\nFounded in 2015 and rapidly expan...
# 4   Business Analyst  Description\nWe are seeking a skilled Business...
# 5   Business Analyst  Description\nWe are delighted to announce that...
# 6   Business Analyst  Description\nWe are seeking a consultative Jun...
# 7   Business Analyst  Description\nIf you are a detail-oriented, cre...
# 8   Business Analyst  Description\nTitle: Business Analyst\nLocation...
# 9   Business Analyst  Description\nJob Title: Junior Business Analys...
# 10  Business Analyst  Description\nThe Business Analyst (BA) will ca...
# 11  Business Analyst  Description\nWe help our clients design and de...
# 12  Business Analyst  Description\nFounded in 2015 and rapidly expan...
# 13  Business Analyst  Description\nWe are seeking a skilled Business...
# 14  Business Analyst  Description\nWe are delighted to announce that...
# 15  Business Analyst  Description\nWe are seeking a consultative Jun...
# 16  Business Analyst  Description\nIf you are a detail-oriented, cre...
# 17  Business Analyst  Description\nTitle: Business Analyst\nLocation...
# 18  Business Analyst  Description\nWe currently have a vacancy for a...
# 19  Business Analyst  Description\nSTEMBoard is seeking to network w...
# 20  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 21  Business Analyst  Description\nTo assist the day-to-day activiti...
# 22  Business Analyst  Description\nWe are looking for Business Analy...
# 23  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 24  Business Analyst  Description\nWe currently have a vacancy for a...
# 25  Business Analyst  Description\nSTEMBoard is seeking to network w...
# 26  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 27  Business Analyst                                                NaN
# 28  Business Analyst  Description\nWe are looking for Business Analy...
# 29  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 30  Business Analyst  Description\nNote: Through proactive pipelinin...
# 31  Business Analyst  Description\nWe're a team of Medicine and Heal...
# 32  Business Analyst  Description\nThe Project Manager will be a mem...
# 33  Business Analyst  Description\nWe currently have a vacancy for a...
# 34  Business Analyst  Description\nDentons is seeking Conflicts & Ri...
# 35  Business Analyst  Description\nFounded in 2016 with only a handf...
# 36  Business Analyst  Description\nNote: Through proactive pipelinin...
# 37  Business Analyst  Description\nWe're a team of Medicine and Heal...
# 38  Business Analyst  Description\nThe Project Manager will be a mem...
# 39  Business Analyst  Description\nWe currently have a vacancy for a...
# 40  Business Analyst  Description\nDentons is seeking Conflicts & Ri...
# 41  Business Analyst  Description\nFounded in 2016 with only a handf...
# 42  Business Analyst  Description\nThe Business Analyst will be work...
# 43  Business Analyst  Description\nAviso Wealth:\nAt Aviso Wealth, w...
# 44  Business Analyst  Description\nRyanair are currently recruiting ...
# 45  Business Analyst  Description\nResource Innovations is seeking a...
# 46  Business Analyst  Description\nWorking at 4most\nWe are not your...
# 47  Business Analyst  Description\nAs a Project Manager at SymSoft y...
# 48  Business Analyst  Description\nThe Business Analyst will be work...
# 49  Business Analyst  Description\nAviso Wealth:\nAt Aviso Wealth, w...
# 50  Business Analyst  Description\nRyanair are currently recruiting ...
# 51  Business Analyst  Description\nResource Innovations is seeking a...
# 52  Business Analyst  Description\nAs a Project Manager at SymSoft y...
# 53  Business Analyst  Description\nAbout the Role\nWe are looking fo...
# ----
# Cloud:
#    Category                                        Description
# 54    Cloud  Description\nWarrCloud is the first and only a...
# 55    Cloud  Description\nResource Innovations is seeking a...
# 56    Cloud  Description\nFor 25 years, TechFlow has been d...
# 57    Cloud  Description\nAbout us\nInnovation is fuelled b...
# 58    Cloud  Description\nWarrCloud is the first and only a...
# 59    Cloud  Description\nResource Innovations is seeking a...
# 60    Cloud  Description\nFor 25 years, TechFlow has been d...
# 61    Cloud  Description\nAbout us\nInnovation is fuelled b...
# 62    Cloud  Description\nWe currently have a vacancy for a...
# 63    Cloud  Description\nAbout us\nInnovation is fuelled b...
# 64    Cloud                                                NaN
# 65    Cloud  Description\nAs a Project Manager at SymSoft y...
# 66    Cloud  Description\nResponsibilies & Deliverables\n• ...
# 67    Cloud  Description\nOptimile is an international soft...
# 68    Cloud  Description\nAs a Data Engineer, you are respo...
# 69    Cloud  Description\nActivities:\nDesigning and implem...
# 70    Cloud  Description\nResponsibilies & Deliverables\n• ...
# 71    Cloud  Description\nOptimile is an international soft...
# 72    Cloud  Description\nAs a Data Engineer, you are respo...
# 73    Cloud  Description\nActivities:\nDesigning and implem...
# 74    Cloud  Description\nThe client is a growing tech comp...
# 75    Cloud  Description\nAbout Us:\nFortanix is a dynamic ...
# 76    Cloud  Description\nThe client is a growing tech comp...
# 77    Cloud  Description\nAbout Us:\nFortanix is a dynamic ...
# 78    Cloud  Description\nJoin our 100% remote team and enj...
# 79    Cloud  Description\nDespite leaps in drone technology...
# 80    Cloud  Description\nDespite leaps in drone technology...
# 81    Cloud  Description\nJoin our 100% remote team and enj...
# 82    Cloud  Description\nWarrCloud is the first and only a...
# 83    Cloud  Description\nThe Staff Software Engineer is a ...
# 84    Cloud  Description\nCloudFactory is seeking a highly-...
# 85    Cloud  Description\nThe Staff Software Engineer is a ...
# 86    Cloud  Description\nCloudFactory is seeking a highly-...
# ----
# Data Scientist:
#            Category                                        Description
# 87   Data Scientist  Description\nData Science problems are everywh...
# 88   Data Scientist  Description\nAre you looking to make a measura...
# 89   Data Scientist  Description\nAs a Data Scientist, you will wor...
# 90   Data Scientist  Description\nAs a member of the Data team at T...
# 91   Data Scientist  Description\nThis is a data science position o...
# ..              ...                                                ...
# 185  Data Scientist  Description\nCollect, prepare, and load files ...
# 186  Data Scientist                                                NaN
# 187  Data Scientist  Description\nMedalogix is searching for a Prod...
# 188  Data Scientist  Description\nWho We Are:\nTickPick is a fast g...
# 189  Data Scientist  Description\nData Analysis: Perform advanced d...
#
# [103 rows x 2 columns]
# ----
# HR:
#     Category                                        Description
# 190       HR  Description\nNew Employee Onboarding:\n·      ...
# 191       HR  Description\nLibrary Systems & Services (LS&S)...
# 192       HR  Description\nNew Employee Onboarding:\n·      ...
# 193       HR  Description\nLibrary Systems & Services (LS&S)...
# 194       HR  Description\nWe are a US-based company seeking...
# 195       HR  Description\nDangote Group, one of Nigeria’s m...
# 196       HR  Description\nWe're Plentific, the world’s lead...
# 197       HR  Description\nAbout us\nLove, Bonito is a digit...
# 198       HR  Description\nA HR Specialist shall be responsi...
# 199       HR  Description\nAbout us\nWith a long history of ...
# 200       HR  Description\nResponsibilities:\n1. Research, q...
# 201       HR  Description\nAbout us\nWith a long history of ...
# 202       HR  Description\nResponsibilities:\n1. Research, q...
# 203       HR  Description\nAbout the Role:\nWe’re building o...
# 204       HR  Description\nAs a full-time Payroll Associate,...
# 205       HR  Description\nCountable.co, a leading tech comp...
# 206       HR  Description\nJoin our 100% remote team and enj...
# 207       HR  Description\nJoin our 100% remote team and enj...
# 208       HR  Description\nZinc’s background-checking produc...
# 209       HR  Description\nJob Brief:\nWe are seeking a high...
# 210       HR  Description\nWorkable makes software to help c...
# 211       HR  Description\nZinc’s background-checking produc...
# 212       HR  Description\nJob Brief:\nWe are seeking a high...
# 213       HR  Description\nWorkable makes software to help c...
# 214       HR  Description\nTrócaire is a social justice orga...
# 215       HR  Description\nJoin our 100% remote team and enj...
# 216       HR  Description\nTrócaire is a social justice orga...
# 217       HR  Description\nJoin our 100% remote team and enj...
# 218       HR                                                NaN
# 219       HR  Description\nAre you someone who thrives in a ...
# 220       HR  Description\nJoin a team of professionals who ...
# 221       HR  Description\nAre you someone who thrives in a ...
# ----
# Software Developer:
#                Category                                        Description
# 222  Software Developer  Description\nWe are seeking a Software Develop...
# 223  Software Developer  Description\nFuturex is seeking talented indiv...
# 224  Software Developer  Description\nDesign (or redesigns) of our inte...
# 225  Software Developer  Description\nWe know that creating an inclusiv...
# 226  Software Developer  Description\nWe need a developer to help us wi...
# ..                  ...                                                ...
# 310  Software Developer  Description\nWe create powerful, beautiful and...
# 311  Software Developer  Description\nRecognized as a leader in develop...
# 312  Software Developer  Description\nDo you want to be part of an amaz...
# 313  Software Developer  Description\nFounded in 2016 in Silicon Valley...
# 314  Software Developer  Description\nWe’re making the world a more wal...
#
# [93 rows x 2 columns]
# ----
# UI/UX:
#     Category                                        Description
# 315    UI/UX  Description\nJob Title: UI/UX Designer\nRequir...
# 316    UI/UX  Description\nThe UX Designer will be focused o...
# 317    UI/UX  Description\nWe are seeking a dynamic UI/UX de...
# 318    UI/UX  Description\nWe are looking for a UI/UX Design...
# 319    UI/UX  Description\nJob Title: UI/UX Designer\nRequir...
# 320    UI/UX  Description\nThe UX Designer will be focused o...
# 321    UI/UX  Description\nWe are seeking a dynamic UI/UX de...
# 322    UI/UX  Description\nWe are looking for a UI/UX Design...
# 323    UI/UX  Description\nRemote – Full-Time\nClay is a glo...
# 324    UI/UX  Description\nRemote – Full-Time\nClay is a glo...
# ----

# %%
data_BA=category_datasets['Business Analyst']
data_cloud=category_datasets['Cloud']
data_DS=category_datasets['Data Scientist']
data_hr=category_datasets['HR']
data_SD=category_datasets['Software Developer']
data_uiux=category_datasets['UI/UX']

# %%
# Drop rows with NaN values in the 'Description' column
data_BA.isnull().sum()
# Out:
# Category       0
# Description    1
# dtype: int64

# %%
data_BA=data_BA.dropna(subset=['Description'])

# %%
data_BA
# Out:
#             Category                                        Description
# 0   Business Analyst  Description\nJob Title: Junior Business Analys...
# 1   Business Analyst  Description\nThe Business Analyst (BA) will ca...
# 2   Business Analyst  Description\nWe help our clients design and de...
# 3   Business Analyst  Description\nFounded in 2015 and rapidly expan...
# 4   Business Analyst  Description\nWe are seeking a skilled Business...
# 5   Business Analyst  Description\nWe are delighted to announce that...
# 6   Business Analyst  Description\nWe are seeking a consultative Jun...
# 7   Business Analyst  Description\nIf you are a detail-oriented, cre...
# 8   Business Analyst  Description\nTitle: Business Analyst\nLocation...
# 9   Business Analyst  Description\nJob Title: Junior Business Analys...
# 10  Business Analyst  Description\nThe Business Analyst (BA) will ca...
# 11  Business Analyst  Description\nWe help our clients design and de...
# 12  Business Analyst  Description\nFounded in 2015 and rapidly expan...
# 13  Business Analyst  Description\nWe are seeking a skilled Business...
# 14  Business Analyst  Description\nWe are delighted to announce that...
# 15  Business Analyst  Description\nWe are seeking a consultative Jun...
# 16  Business Analyst  Description\nIf you are a detail-oriented, cre...
# 17  Business Analyst  Description\nTitle: Business Analyst\nLocation...
# 18  Business Analyst  Description\nWe currently have a vacancy for a...
# 19  Business Analyst  Description\nSTEMBoard is seeking to network w...
# 20  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 21  Business Analyst  Description\nTo assist the day-to-day activiti...
# 22  Business Analyst  Description\nWe are looking for Business Analy...
# 23  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 24  Business Analyst  Description\nWe currently have a vacancy for a...
# 25  Business Analyst  Description\nSTEMBoard is seeking to network w...
# 26  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 28  Business Analyst  Description\nWe are looking for Business Analy...
# 29  Business Analyst  Description\nFinexio is the leader in AP Payme...
# 30  Business Analyst  Description\nNote: Through proactive pipelinin...
# 31  Business Analyst  Description\nWe're a team of Medicine and Heal...
# 32  Business Analyst  Description\nThe Project Manager will be a mem...
# 33  Business Analyst  Description\nWe currently have a vacancy for a...
# 34  Business Analyst  Description\nDentons is seeking Conflicts & Ri...
# 35  Business Analyst  Description\nFounded in 2016 with only a handf...
# 36  Business Analyst  Description\nNote: Through proactive pipelinin...
# 37  Business Analyst  Description\nWe're a team of Medicine and Heal...
# 38  Business Analyst  Description\nThe Project Manager will be a mem...
# 39  Business Analyst  Description\nWe currently have a vacancy for a...
# 40  Business Analyst  Description\nDentons is seeking Conflicts & Ri...
# 41  Business Analyst  Description\nFounded in 2016 with only a handf...
# 42  Business Analyst  Description\nThe Business Analyst will be work...
# 43  Business Analyst  Description\nAviso Wealth:\nAt Aviso Wealth, w...
# 44  Business Analyst  Description\nRyanair are currently recruiting ...
# 45  Business Analyst  Description\nResource Innovations is seeking a...
# 46  Business Analyst  Description\nWorking at 4most\nWe are not your...
# 47  Business Analyst  Description\nAs a Project Manager at SymSoft y...
# 48  Business Analyst  Description\nThe Business Analyst will be work...
# 49  Business Analyst  Description\nAviso Wealth:\nAt Aviso Wealth, w...
# 50  Business Analyst  Description\nRyanair are currently recruiting ...
# 51  Business Analyst  Description\nResource Innovations is seeking a...
# 52  Business Analyst  Description\nAs a Project Manager at SymSoft y...
# 53  Business Analyst  Description\nAbout the Role\nWe are looking fo...

# %%
# Preprocess the text data
def preprocess_text(text):
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# Apply preprocessing to the Description column
data_BA['Description'] = data_BA['Description'].apply(preprocess_text)
# Out:
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/1811990132.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_BA['Description'] = data_BA['Description'].apply(preprocess_text)

# %%
data_BA
# Out:
#             Category                                        Description
# 0   Business Analyst  [description, job, title, junior, business, an...
# 1   Business Analyst  [description, business, analyst, ba, capture, ...
# 2   Business Analyst  [description, help, clients, design, deliver, ...
# 3   Business Analyst  [description, founded, rapidly, expanding, fre...
# 4   Business Analyst  [description, seeking, skilled, business, anal...
# 5   Business Analyst  [description, delighted, announce, application...
# 6   Business Analyst  [description, seeking, consultative, junior, b...
# 7   Business Analyst  [description, detailoriented, creative, proble...
# 8   Business Analyst  [description, title, business, analyst, locati...
# 9   Business Analyst  [description, job, title, junior, business, an...
# 10  Business Analyst  [description, business, analyst, ba, capture, ...
# 11  Business Analyst  [description, help, clients, design, deliver, ...
# 12  Business Analyst  [description, founded, rapidly, expanding, fre...
# 13  Business Analyst  [description, seeking, skilled, business, anal...
# 14  Business Analyst  [description, delighted, announce, application...
# 15  Business Analyst  [description, seeking, consultative, junior, b...
# 16  Business Analyst  [description, detailoriented, creative, proble...
# 17  Business Analyst  [description, title, business, analyst, locati...
# 18  Business Analyst  [description, currently, vacancy, business, an...
# 19  Business Analyst  [description, stemboard, seeking, network, str...
# 20  Business Analyst  [description, finexio, leader, ap, payments, s...
# 21  Business Analyst  [description, assist, daytoday, activities, cc...
# 22  Business Analyst  [description, looking, business, analysts, joi...
# 23  Business Analyst  [description, finexio, leader, ap, payments, s...
# 24  Business Analyst  [description, currently, vacancy, business, an...
# 25  Business Analyst  [description, stemboard, seeking, network, str...
# 26  Business Analyst  [description, finexio, leader, ap, payments, s...
# 28  Business Analyst  [description, looking, business, analysts, joi...
# 29  Business Analyst  [description, finexio, leader, ap, payments, s...
# 30  Business Analyst  [description, note, proactive, pipelining, col...
# 31  Business Analyst  [description, team, medicine, healthcare, exec...
# 32  Business Analyst  [description, project, manager, member, pmo, t...
# 33  Business Analyst  [description, currently, vacancy, business, an...
# 34  Business Analyst  [description, dentons, seeking, conflicts, ris...
# 35  Business Analyst  [description, founded, handful, individuals, q...
# 36  Business Analyst  [description, note, proactive, pipelining, col...
# 37  Business Analyst  [description, team, medicine, healthcare, exec...
# 38  Business Analyst  [description, project, manager, member, pmo, t...
# 39  Business Analyst  [description, currently, vacancy, business, an...
# 40  Business Analyst  [description, dentons, seeking, conflicts, ris...
# 41  Business Analyst  [description, founded, handful, individuals, q...
# 42  Business Analyst  [description, business, analyst, working, vari...
# 43  Business Analyst  [description, aviso, wealth, aviso, wealth, de...
# 44  Business Analyst  [description, ryanair, currently, recruiting, ...
# 45  Business Analyst  [description, resource, innovations, seeking, ...
# 46  Business Analyst  [description, working, typical, consultancy, f...
# 47  Business Analyst  [description, project, manager, symsoft, suppo...
# 48  Business Analyst  [description, business, analyst, working, vari...
# 49  Business Analyst  [description, aviso, wealth, aviso, wealth, de...
# 50  Business Analyst  [description, ryanair, currently, recruiting, ...
# 51  Business Analyst  [description, resource, innovations, seeking, ...
# 52  Business Analyst  [description, project, manager, symsoft, suppo...
# 53  Business Analyst  [description, role, looking, business, intelli...

# %%
# Create bigrams and trigrams
bigram = Phrases(data_BA['Description'], min_count=5, threshold=100)
trigram = Phrases(bigram[data_BA['Description']], min_count=5, threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
data_BA['Description'] = [bigram_mod[doc] for doc in data_BA['Description']]
data_BA['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_BA['Description']]

# Create a dictionary representation of the documents
dictionary_BA= corpora.Dictionary(data_BA['Description'])

# Convert the documents into a bag-of-words format
bow_corpus_BA= [dictionary_BA.doc2bow(doc) for doc in data_BA['Description']]

# Train the LDA model
lda_model_BA= LdaModel(bow_corpus_BA, num_topics=3, id2word=dictionary_BA, passes=10)

# Print the topics
for idx, topic in lda_model_BA.print_topics(-1):
    print(f'Topic: {idx} \nWords: {topic}\n')
# Out:
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/681428599.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_BA['Description'] = [bigram_mod[doc] for doc in data_BA['Description']]
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/681428599.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_BA['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_BA['Description']]
# Topic: 0
# Words: 0.024*"business" + 0.014*"process" + 0.011*"work" + 0.009*"team" + 0.009*"requirements" + 0.007*"stakeholders" + 0.007*"teams" + 0.006*"data" + 0.006*"clients" + 0.006*"project"
#
# Topic: 1
# Words: 0.024*"business" + 0.010*"requirements" + 0.010*"analyst" + 0.009*"support" + 0.008*"development" + 0.007*"team" + 0.007*"client" + 0.007*"technical" + 0.006*"delivery" + 0.006*"teams"
#
# Topic: 2
# Words: 0.022*"business" + 0.022*"data" + 0.009*"team" + 0.008*"project" + 0.008*"work" + 0.007*"clients" + 0.006*"management" + 0.006*"analyst" + 0.006*"healthcare" + 0.006*"teams"

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Prepare the visualization
lda_vis_data_BA= gensimvis.prepare(lda_model_BA, bow_corpus_BA, dictionary_BA)

# Display the visualization
pyLDAvis.display(lda_vis_data_BA)
# Out:
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/rohini/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2127559639964484837866168" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2127559639964484837866168_data = {"mdsDat": {"x": [0.10130487793900267, -0.09364873746981503, -0.007656140469187678], "y": [-0.045320513571400274, -0.05742551668123195, 0.10274603025263224], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [46.219726194189455, 33.40964417395559, 20.370629631854953]}, "tinfo": {"Term": ["process", "healthcare", "business", "risk", "stakeholders", "work", "payments", "data", "perform", "delivery", "support", "requirements", "looking", "high", "aviso_wealth", "quantexa", "project", "conflict", "processes", "document", "methods", "needed", "organization", "documentation", "finexio", "define", "ensure", "assigned", "tools", "testing", "healthcare", "payments", "finexio", "intelligence", "fresh_gravity", "engineers", "labs", "test_plans", "year", "experts", "unique", "bi", "fluent", "investors", "revenue", "mission", "bank", "functions", "bb", "curation", "directly", "top", "subject_matter", "highly", "leader", "requires", "fast_paced", "executive", "leads", "premises", "position", "data", "decisions", "members", "enhance", "project", "analysts", "management", "business", "ryanair", "team", "manager", "clients", "company", "work", "make", "also", "us", "environment", "description", "sources", "customer", "teams", "product", "customers", "developing", "analyst", "develop", "solutions", "role", "software", "requirements", "experience", "knowledge", "systems", "projects", "development", "technical", "tools", "portfolio", "energy", "resource_innovations", "success_factors", "relevant", "products", "learning", "acceptance", "jazz", "drivers_impacting", "functionality", "good", "foundation", "pathway", "early", "detailed", "supported", "uk", "saas_platforms", "utility", "modeling", "forecasting", "sheets", "title", "onboarding", "integrations", "modules", "interactive", "raising", "performance", "contribute", "junior", "methods", "configuration", "professional", "testing", "internal", "external", "ensure", "support", "development", "client", "business", "analyst", "user", "requirements", "delivery", "new", "skills", "technical", "software", "analysis", "knowledge", "existing", "identify", "team", "teams", "role", "clients", "experience", "systems", "manage", "solutions", "work", "projects", "description", "data", "product", "working", "process", "aviso_wealth", "quantexa", "conflict", "goals", "legal", "dentons", "completed", "engineering", "capabilities", "ways", "monitoring", "getting", "outside", "commercial", "resolution", "complexity", "confidential", "checks", "terms", "intake", "completion", "high", "ccocfo", "requiring", "exemplify", "promptly", "performing", "discovery", "optimize", "georgia", "risk", "needed", "assigned", "communicate", "features", "continuous", "due", "process", "perform", "document", "stakeholders", "business", "work", "looking", "value", "organization", "processes", "documentation", "requirements", "team", "teams", "key", "projects", "delivery", "project", "clients", "within", "role", "technical", "support", "define", "customer", "analyst", "data", "management", "description", "help", "working", "deliver"], "Freq": [52.0, 29.0, 232.0, 12.0, 32.0, 77.0, 22.0, 131.0, 17.0, 38.0, 56.0, 77.0, 26.0, 9.0, 7.0, 7.0, 56.0, 7.0, 24.0, 13.0, 18.0, 8.0, 17.0, 25.0, 15.0, 22.0, 27.0, 8.0, 9.0, 19.0, 28.69481463480469, 21.613819231924406, 14.514925095875789, 10.084341824867256, 9.196933277572954, 9.17742833104017, 9.175558201136372, 9.174045007535787, 8.292554572311253, 8.282742068848412, 8.28200223723812, 7.4146892038146435, 7.406959910412366, 7.4060881205324, 7.406264425433683, 7.405562991516614, 7.405224983653724, 7.404044389790222, 7.401228378682912, 7.401164562798399, 7.400681076351321, 7.399607563378782, 7.392229257341329, 7.392741406855181, 7.392045381063917, 7.387699951978603, 7.386508541863488, 7.375836687210035, 6.497043825137656, 5.6325013745647174, 18.184234619394115, 100.75934568813908, 14.519094760872399, 14.477903229856592, 13.644085964426646, 38.501248017241 ...

# %% [markdown]
# **FOR CLOUD**

# %%
# Preprocess the text data
def preprocess_text(text):
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# Apply preprocessing to the Description column
data_cloud['Description'] = data_cloud['Description'].apply(preprocess_text)

# %%
# Create bigrams and trigrams
bigram = Phrases(data_cloud['Description'], min_count=5, threshold=100)
trigram = Phrases(bigram[data_cloud['Description']], min_count=5, threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
data_cloud['Description'] = [bigram_mod[doc] for doc in data_cloud['Description']]
data_cloud['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_cloud['Description']]

# Create a dictionary representation of the documents
dictionary_cloud= corpora.Dictionary(data_cloud['Description'])

# Convert the documents into a bag-of-words format
bow_corpus_cloud= [dictionary_cloud.doc2bow(doc) for doc in data_cloud['Description']]

# Train the LDA model
lda_model_cloud= LdaModel(bow_corpus_cloud, num_topics=3, id2word=dictionary_cloud, passes=10)

# Print the topics
for idx, topic in lda_model_cloud.print_topics(-1):
    print(f'Topic: {idx} \nWords: {topic}\n')
    
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Prepare the visualization
lda_vis_data_cloud= gensimvis.prepare(lda_model_cloud, bow_corpus_cloud, dictionary_cloud)

# Display the visualization
pyLDAvis.display(lda_vis_data_cloud)
# Out:
# Topic: 0
# Words: 0.017*"data" + 0.013*"software" + 0.009*"cloudline" + 0.006*"team" + 0.006*"work" + 0.006*"development" + 0.006*"operations" + 0.005*"training" + 0.005*"build" + 0.005*"description"
#
# Topic: 1
# Words: 0.019*"product" + 0.017*"cloud" + 0.009*"work" + 0.009*"solutions" + 0.009*"architecture" + 0.009*"technology" + 0.008*"team" + 0.008*"client" + 0.007*"saas" + 0.007*"content"
#
# Topic: 2
# Words: 0.015*"work" + 0.013*"warranty" + 0.011*"team" + 0.008*"services" + 0.007*"company" + 0.007*"join" + 0.007*"opportunity" + 0.006*"make" + 0.006*"commission" + 0.006*"warrcloud"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2127559640008165574694856" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2127559640008165574694856_data = {"mdsDat": {"x": [0.09241443237769133, -0.15211793908187593, 0.05970350670418464], "y": [0.11421490777421411, 0.017637852225700308, -0.1318527599999144], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [39.245428669214995, 30.385497867321742, 30.369073463463263]}, "tinfo": {"Term": ["product", "warranty", "data", "cloud", "cloudline", "client", "architecture", "content", "commission", "warrcloud", "administrator", "saas", "future", "opportunity", "energy", "techflow", "software", "oems", "employees", "automotive", "great", "fortanix", "work", "people", "manage", "campaigns", "efficiency", "azure", "career", "job", "cloudline", "optimile", "airship", "flight", "life", "scale", "learn", "various", "africa", "ingest", "science", "data", "ai", "simply", "push", "mobility", "scientists", "app", "expected", "interview", "cloudfactory", "charging", "builder", "local", "type", "run", "point", "value", "get", "head", "software", "systems", "everyone", "engineering", "development", "process", "training", "operations", "build", "platform", "world", "applications", "developing", "quality", "processing", "design", "description", "team", "models", "new", "building", "work", "solutions", "technology", "infrastructure", "teams", "code", "warranty", "commission", "warrcloud", "administrator", "future", "techflow", "oems", "employees", "automotive", "career", "job", "emi", "level", "enjoy", "dealership", "employee", "hiring", "payments", "repair_orders", "dealerships", "becomes", "claims", "well", "gm", "user", "delivering", "home", "top", "directly", "year", "azure", "opportunity", "company", "work", "join", "services", "team", "apply", "days", "make", "assigned", "first", "support", "customers", "ensure", "digital", "customer", "new", "description", "solutions", "us", "take", "client", "energy", "great", "fortanix", "people", "campaigns", "manage", "efficiency", "kubernetes", "content", "resources", "product", "comprehensive", "departments", "things", "coordinate", "rest", "additional", "passionate", "focused", "document", "recognize", "launches", "driving", "computing", "change", "within", "external", "iaas", "francisco", "architecture", "cloud", "saas", "products", "position", "automation", "cicd", "portfolio", "delivery", "lifecycle", "policies", "technology", "solutions", "marketing", "opportunities", "including", "industry", "benefits", "effectively", "work", "candidates", "define", "team", "description", "responsible", "infrastructure", "software", "building", "development", "like", "teams", "develop", "new"], "Freq": [36.0, 22.0, 40.0, 35.0, 20.0, 13.0, 17.0, 12.0, 10.0, 10.0, 10.0, 13.0, 9.0, 15.0, 8.0, 8.0, 38.0, 7.0, 7.0, 7.0, 7.0, 7.0, 54.0, 7.0, 7.0, 7.0, 7.0, 10.0, 7.0, 7.0, 20.026987697192475, 8.507085145669606, 8.502247114235383, 8.501589611969717, 6.8700337567459995, 6.86343523361987, 6.861517390958404, 6.8582191511548825, 6.855732699307959, 5.227838319405159, 5.224389880948874, 36.576563924510154, 5.222011224733695, 5.220625718793925, 5.220416768967463, 5.220320212690687, 5.21983487690795, 5.218647081439674, 5.218412076744876, 5.217197715528492, 5.217027592564649, 5.216602029715155, 5.216319513201626, 5.204911057028693, 5.204435938841383, 4.396812674139038, 4.395611084916936, 4.395221283651433, 4.395171728313618, 4.393028587673008, 28.279439125490473, 8.509636479247487, 7.6942284285900495, 10.171351610890213, 12.654048491495274, 10.19305480533464, 11.789681810594479, 12.562404834600136, 11.012175930169896, 10.171022604317494, 9.343398396568698, 8.51133821976569, 9.249883897951054, 6.893113772174085, 6.878158788628778, 9.24419780609647, 10.849008083533013, 13.99011761755549, 6.0565680709790515, 9.36346677574496, 8.518845087125195, 12.662497421153057, 10.207821274244337, 8.539550022496499, 7.563241409627216, 7.7183123227687425, 6.888690575114158, 21.53752450732094, 9.717752303220516, 9.713949532826604, 9.712684579662497, 8.909917138910224, 8.12154200141912, 7.354845898642964, 7.3 ...

# %% [markdown]
# **DATA SCIENTIST**

# %%
data_DS
# Out:
#            Category                                        Description
# 87   Data Scientist  Description\nData Science problems are everywh...
# 88   Data Scientist  Description\nAre you looking to make a measura...
# 89   Data Scientist  Description\nAs a Data Scientist, you will wor...
# 90   Data Scientist  Description\nAs a member of the Data team at T...
# 91   Data Scientist  Description\nThis is a data science position o...
# ..              ...                                                ...
# 185  Data Scientist  Description\nCollect, prepare, and load files ...
# 186  Data Scientist                                                NaN
# 187  Data Scientist  Description\nMedalogix is searching for a Prod...
# 188  Data Scientist  Description\nWho We Are:\nTickPick is a fast g...
# 189  Data Scientist  Description\nData Analysis: Perform advanced d...
#
# [103 rows x 2 columns]

# %%
# Drop rows with NaN values in the 'Description' column
data_DS = data_DS.dropna(subset=['Description'])

# %%
data_DS['Description']
# Out:
# 87     Description\nData Science problems are everywh...
# 88     Description\nAre you looking to make a measura...
# 89     Description\nAs a Data Scientist, you will wor...
# 90     Description\nAs a member of the Data team at T...
# 91     Description\nThis is a data science position o...
#                              ...
# 184    Description\nData Analysis: Perform advanced d...
# 185    Description\nCollect, prepare, and load files ...
# 187    Description\nMedalogix is searching for a Prod...
# 188    Description\nWho We Are:\nTickPick is a fast g...
# 189    Description\nData Analysis: Perform advanced d...
# Name: Description, Length: 100, dtype: object

# %%
# Preprocess the text data
def preprocess_text(text):
     # Check if text is empty or contains only a single token
    if not text or len(text) == 1:
        return []
    
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens


# Apply preprocessing to the Description column
data_DS['Description'] = data_DS['Description'].apply(preprocess_text)
# Out:
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/326113863.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_DS['Description'] = data_DS['Description'].apply(preprocess_text)

# %%
data_DS['Description']
# Out:
# 87     [description, data, science, problems, everywh...
# 88     [description, looking, make, measurable, impac...
# 89     [description, data, scientist, work, closely, ...
# 90     [description, member, data, team, trexquant, i...
# 91     [description, data, science, position, interna...
#                              ...
# 184    [description, data, analysis, perform, advance...
# 185    [description, collect, prepare, load, files, d...
# 187    [description, medalogix, searching, product, o...
# 188    [description, tickpick, fast, growing, technol...
# 189    [description, data, analysis, perform, advance...
# Name: Description, Length: 100, dtype: object

# %%
# Create bigrams and trigrams
bigram = Phrases(data_DS['Description'], min_count=5, threshold=100)
trigram = Phrases(bigram[data_DS['Description']], min_count=5, threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
data_DS['Description'] = [bigram_mod[doc] for doc in data_DS['Description']]
data_DS['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_DS['Description']]

# Create a dictionary representation of the documents
dictionary_DS= corpora.Dictionary(data_DS['Description'])

# Convert the documents into a bag-of-words format
bow_corpus_DS= [dictionary_DS.doc2bow(doc) for doc in data_DS['Description']]

# Train the LDA model
lda_model_DS = LdaModel(bow_corpus_DS, num_topics=3, id2word=dictionary_DS, passes=10)

# Print the topics
for idx, topic in lda_model_DS.print_topics(-1):
    print(f'Topic: {idx} \nWords: {topic}\n')
    
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Prepare the visualization
lda_vis_data_DS = gensimvis.prepare(lda_model_DS, bow_corpus_DS, dictionary_DS)

# Display the visualization
pyLDAvis.display(lda_vis_data_DS)
# Out:
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/1589208032.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_DS['Description'] = [bigram_mod[doc] for doc in data_DS['Description']]
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/1589208032.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_DS['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_DS['Description']]
# Topic: 0
# Words: 0.041*"data" + 0.015*"business" + 0.014*"team" + 0.010*"analytics" + 0.007*"models" + 0.007*"work" + 0.007*"develop" + 0.007*"looking" + 0.006*"solutions" + 0.006*"new"
#
# Topic: 1
# Words: 0.055*"data" + 0.014*"business" + 0.012*"team" + 0.007*"work" + 0.007*"product" + 0.007*"teams" + 0.006*"science" + 0.006*"analytics" + 0.006*"analysis" + 0.005*"description"
#
# Topic: 2
# Words: 0.034*"data" + 0.011*"team" + 0.008*"work" + 0.008*"business" + 0.007*"science" + 0.007*"models" + 0.006*"learning" + 0.006*"analysis" + 0.006*"tools" + 0.005*"projects"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2127559640046245948796339" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2127559640046245948796339_data = {"mdsDat": {"x": [-0.022973265290063445, -0.08964510109598746, 0.11261836638605088], "y": [-0.10074218268008135, 0.06753467197143967, 0.033207510708641655], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [37.18436856765581, 35.28789928762655, 27.527732144717643]}, "tinfo": {"Term": ["analytics", "love_bonito", "pipelines", "healthcare", "youll", "sets", "insights", "data", "challenges", "carwow", "research", "business", "looking", "dynamic", "relationship", "may", "learn", "models", "sources", "user", "fabulous", "approach", "internal", "assessments", "identify", "ml", "obviously_ai", "join", "medalogix", "great", "healthcare", "medalogix", "fabulous", "app", "bi", "finance", "recommendations", "cloud", "sculptor", "committed", "providers", "dbt", "modern", "integrity", "collaboration", "natural", "dss", "review", "home", "datarelated", "optimize", "implementing", "restoring", "component", "since", "companys", "ecosystems", "code_base", "awards", "mvp", "pipelines", "agile", "user", "effectively", "datasets", "crossfunctional", "would", "expected", "model", "data", "practices", "product", "technologies", "highly", "engineer", "teams", "business", "identify", "understanding", "team", "ensure", "analysis", "analytics", "work", "technology", "science", "skills", "insights", "stakeholders", "quality", "health", "description", "help", "solutions", "responsibilities", "build", "support", "drive", "engineers", "projects", "role", "management", "learning", "develop", "engineering", "challenges", "assessments", "obviously_ai", "nmi", "ground_floor", "small_scrappy", "operational", "integrations", "wwc_global", "giskard", "without", "speed", "natural_language_processing_nlp", "agency", "backed", "employment", "startup", "ab_tests", "throughout_organization", "concepts_layman_terms", "adapt", "hire", "hours", "hands", "real", "track_record", "program", "ecommerce", "limited", "bias_action", "may", "several", "activities", "strategic", "access", "internal", "ml", "ai", "results", "supporting", "excited", "position", "youre", "keep", "providing", "tools", "data", "projects", "models", "analysis", "science", "work", "support", "team", "learning", "machine", "analytical", "complex", "success", "across", "engineering", "new", "business", "develop", "product", "problems", "techniques", "build", "teams", "description", "company", "development", "working", "love_bonito", "carwow", "relationship", "materials", "could", "qr_", "australia", "alten_group", "taking", "output", "hundreds", "weve", "marketers", "collaborating_alpha_strategy", "derived_variables", "discovering_obtaining", "visualisations", "signals_systematic", "pricing", "sales_forecast", "orderbyorder_tick", "philippines_united_states_america", "loosely_defined", "trexquant_involved", "look", "starter_getyourhands", "vital_trading", "corporatebs", "framework_automatically_download", "femalefounded_female", "fit", "done", "sets", "efficiently", "dynamic", "decision", "great", "youll", "learn", "approach", "research", "analytics", "things", "ability", "looking", "data", "large", "business", "insights", "team", "solutions", "models", "develop", "design", "working", "new", "people", "join", "learning", "scientist", "work", "machine", "description", "performance", "stakeholders", "role", "us", "science", "build", "products"], "Freq": [110.0, 26.0, 38.0, 29.0, 41.0, 28.0, 67.0, 871.0, 19.0, 14.0, 40.0, 241.0, 69.0, 25.0, 13.0, 22.0, 27.0, 105.0, 36.0, 27.0, 16.0, 19.0, 30.0, 15.0, 42.0, 34.0, 14.0, 37.0, 15.0, 18.0, 28.01720519970505, 14.401717751165931, 16.081571201116496, 10.892279855553564, 10.858647605116591, 9.108696215254268, 9.09778394821308, 10.72270274403165, 8.24051982781381, 8.239007628108748, 10.709152299234248, 8.235394004126404, 8.232310252168128, 10.694862098039602, 9.839616824459322, 7.364768678938328, 7.3567870514848215, 7.352305504008501, 7.350524927563975, 7.349618295886424, 7.346291112462546, 6.4681598403880285, 5.5945914 ...

# %% [markdown]
# **HR**

# %%
data_hr
# Out:
#     Category                                        Description
# 190       HR  Description\nNew Employee Onboarding:\n·      ...
# 191       HR  Description\nLibrary Systems & Services (LS&S)...
# 192       HR  Description\nNew Employee Onboarding:\n·      ...
# 193       HR  Description\nLibrary Systems & Services (LS&S)...
# 194       HR  Description\nWe are a US-based company seeking...
# 195       HR  Description\nDangote Group, one of Nigeria’s m...
# 196       HR  Description\nWe're Plentific, the world’s lead...
# 197       HR  Description\nAbout us\nLove, Bonito is a digit...
# 198       HR  Description\nA HR Specialist shall be responsi...
# 199       HR  Description\nAbout us\nWith a long history of ...
# 200       HR  Description\nResponsibilities:\n1. Research, q...
# 201       HR  Description\nAbout us\nWith a long history of ...
# 202       HR  Description\nResponsibilities:\n1. Research, q...
# 203       HR  Description\nAbout the Role:\nWe’re building o...
# 204       HR  Description\nAs a full-time Payroll Associate,...
# 205       HR  Description\nCountable.co, a leading tech comp...
# 206       HR  Description\nJoin our 100% remote team and enj...
# 207       HR  Description\nJoin our 100% remote team and enj...
# 208       HR  Description\nZinc’s background-checking produc...
# 209       HR  Description\nJob Brief:\nWe are seeking a high...
# 210       HR  Description\nWorkable makes software to help c...
# 211       HR  Description\nZinc’s background-checking produc...
# 212       HR  Description\nJob Brief:\nWe are seeking a high...
# 213       HR  Description\nWorkable makes software to help c...
# 214       HR  Description\nTrócaire is a social justice orga...
# 215       HR  Description\nJoin our 100% remote team and enj...
# 216       HR  Description\nTrócaire is a social justice orga...
# 217       HR  Description\nJoin our 100% remote team and enj...
# 218       HR                                                NaN
# 219       HR  Description\nAre you someone who thrives in a ...
# 220       HR  Description\nJoin a team of professionals who ...
# 221       HR  Description\nAre you someone who thrives in a ...

# %%
# Drop rows with NaN values in the 'Description' column
data_hr = data_hr.dropna(subset=['Description'])

# %%
# Preprocess the text data
def preprocess_text(text):
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# Apply preprocessing to the Description column
data_hr['Description'] = data_hr['Description'].apply(preprocess_text)
# Out:
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/959317425.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_hr['Description'] = data_hr['Description'].apply(preprocess_text)

# %%
# Create bigrams and trigrams
bigram = Phrases(data_hr['Description'], min_count=5, threshold=100)
trigram = Phrases(bigram[data_hr['Description']], min_count=5, threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
data_hr['Description'] = [bigram_mod[doc] for doc in data_hr['Description']]
data_hr['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_hr['Description']]

# Create a dictionary representation of the documents
dictionary_hr = corpora.Dictionary(data_hr['Description'])

# Convert the documents into a bag-of-words format
bow_corpus_hr = [dictionary_hr.doc2bow(doc) for doc in data_hr['Description']]

# Train the LDA model
lda_model_hr= LdaModel(bow_corpus_hr, num_topics=3, id2word=dictionary_hr, passes=10)

# Print the topics
for idx, topic in lda_model_hr.print_topics(-1):
    print(f'Topic: {idx} \nWords: {topic}\n')
    
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Prepare the visualization
lda_vis_data_hr = gensimvis.prepare(lda_model_hr, bow_corpus_hr, dictionary_hr)

# Display the visualization
pyLDAvis.display(lda_vis_data_hr)
# Out:
# Topic: 0
# Words: 0.016*"team" + 0.009*"scrum" + 0.008*"administration" + 0.008*"support" + 0.007*"hr" + 0.007*"development" + 0.007*"ensuring" + 0.007*"finance" + 0.006*"work" + 0.006*"role"
#
# Topic: 1
# Words: 0.019*"hr" + 0.014*"management" + 0.013*"legal" + 0.012*"employee" + 0.011*"business" + 0.009*"manage" + 0.008*"support" + 0.008*"new" + 0.007*"strategic" + 0.007*"provide"
#
# Topic: 2
# Words: 0.012*"team" + 0.010*"work" + 0.008*"join" + 0.008*"people" + 0.007*"hr" + 0.007*"take" + 0.007*"support" + 0.006*"us" + 0.006*"time" + 0.006*"description"
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/895795411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_hr['Description'] = [bigram_mod[doc] for doc in data_hr['Description']]
# /var/folders/wz/2r9dmd592pg7wwm18rccbml80000gn/T/ipykernel_21275/895795411.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_hr['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_hr['Description']]
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2127559615678087873759656" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2127559615678087873759656_data = {"mdsDat": {"x": [0.1134632813100265, -0.14313022199767192, 0.02966694068764549], "y": [-0.08281668952948165, -0.04016116594268657, 0.12297785547216822], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [46.53271521635502, 33.24558221651935, 20.221702567125625]}, "tinfo": {"Term": ["legal", "scrum", "administration", "manage", "provide", "employee", "team", "business", "management", "finance", "ensuring", "corporate", "strategic", "hr", "justice", "plans", "people", "operations", "guidance", "potential", "vp", "laws_regulations", "us", "organization", "new", "product", "overall", "tr\u00f3caire", "country", "compliance", "user", "world", "marketing", "sales", "make", "customer", "creative", "clients", "need", "someone", "danaos_shipping", "well", "career_next_level", "regex_seo", "exciting", "us", "enjoy", "applications", "laravel", "standards", "hiring", "roles", "interfaces", "helped", "customers", "designers_developers", "ui", "find", "intuitive", "per", "design", "take", "time", "opportunity", "people", "looking", "candidates", "skills", "join", "digital", "work", "experience", "team", "apply", "description", "projects", "support", "talent", "hr", "role", "across", "ensure", "issues", "legal", "provide", "potential", "vp", "laws_regulations", "participants", "external", "statutory", "governance", "matters", "various", "executive", "manage", "overall", "developing", "lss", "corporate", "stay", "oversee", "plans", "advice", "review", "drive", "manager", "guidance", "recruit", "referrals", "litigation", "deal", "transactions", "strategies", "succession_planning", "strategic", "etc", "business", "employee", "compliance", "management", "hr", "advise", "new", "leadership", "compensation", "develop", "needs", "operations", "hrrelated", "implement", "support", "including", "development", "human", "team", "talent", "description", "issues", "scrum", "justice", "tr\u00f3caire", "country", "colleagues", "womens", "administration", "accountants", "society", "organisations", "leone", "sierra", "logistics", "works", "plays", "head", "political", "civil", "five", "continuous", "climate", "officer", "components", "empowerment", "positive", "budgeting", "lasting", "facilitating", "requests", "owner", "adoption", "finance", "change", "product", "team", "ensuring", "development", "support", "role", "social", "reporting", "ensure", "including", "hr", "work", "organization", "operations", "promote", "teams", "changes", "environment", "management", "people"], "Freq": [23.0, 10.0, 10.0, 16.0, 12.0, 27.0, 57.0, 24.0, 37.0, 9.0, 14.0, 12.0, 14.0, 59.0, 6.0, 12.0, 23.0, 14.0, 11.0, 8.0, 8.0, 8.0, 17.0, 12.0, 20.0, 8.0, 8.0, 4.0, 4.0, 12.0, 10.111871186557666, 10.106512490341045, 10.103425241475945, 10.080577086200083, 9.287431774603307, 9.252422006847759, 8.475371065167263, 8.465023868378832, 8.451076975976232, 7.650239821537175, 6.835266677846082, 6.828237530911187, 6.828103849150559, 6.824408176887731, 6.8225080677601735, 15.854760785170402, 6.8206136715283705, 6.819793870987767, 6.817209928238537, 6.016320786448125, 6.005595967250401, 6.00515664556697, 5.1960957776909975, 5.193419286030562, 5.193409574107782, 5.193546683605862, 5.194052274880032, 5.190149795790933, 5.191106705829616, 5.186467263188337, 10.33228613051259, 16.64079011381683, 14.2027318705433, 10.10766992302067, 19.94197321392796, 11.738440009970484, 8.47259402654157, 7.826147879836218, 20.802093087599307, 10.112161401661936, 25.496603473622958, 10.721284057831639, 29.49955183259807, 9.289494701259835, 13.719555714151477, 9.241398403202137, 16.05029835327788, 11.492407298878483, 18.216970054106138, 10.685110001921563, 9.141423870098036, 9.100275024565962, 8.63345717387422, 22.66458758606218, 12.143797683917171, 8.274065906708733, 8.221009016497675, 8.212157630074744, 6.678591463216186, 6.660342570521853, 6.660327468552949, 6.659242575759804, 5.82307349620187, 5.069636675751022, 5.777234938965523, 15.249863709791008, 7.935186704055824,  ...

# %% [markdown]
# **SOFTWARE DEVELOPER**

# %%
data_SD
# Out:
#                Category                                        Description
# 222  Software Developer  Description\nWe are seeking a Software Develop...
# 223  Software Developer  Description\nFuturex is seeking talented indiv...
# 224  Software Developer  Description\nDesign (or redesigns) of our inte...
# 225  Software Developer  Description\nWe know that creating an inclusiv...
# 226  Software Developer  Description\nWe need a developer to help us wi...
# ..                  ...                                                ...
# 310  Software Developer  Description\nWe create powerful, beautiful and...
# 311  Software Developer  Description\nRecognized as a leader in develop...
# 312  Software Developer  Description\nDo you want to be part of an amaz...
# 313  Software Developer  Description\nFounded in 2016 in Silicon Valley...
# 314  Software Developer  Description\nWe’re making the world a more wal...
#
# [93 rows x 2 columns]

# %%
# Preprocess the text data
def preprocess_text(text):
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# Apply preprocessing to the Description column
data_SD['Description'] = data_SD['Description'].apply(preprocess_text)

# %%
# Create bigrams and trigrams
bigram = Phrases(data_SD['Description'], min_count=5, threshold=100)
trigram = Phrases(bigram[data_SD['Description']], min_count=5, threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
data_SD['Description'] = [bigram_mod[doc] for doc in data_SD['Description']]
data_SD['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_SD['Description']]

# Create a dictionary representation of the documents
dictionary_SD = corpora.Dictionary(data_SD['Description'])

# Convert the documents into a bag-of-words format
bow_corpus_SD = [dictionary_SD.doc2bow(doc) for doc in data_SD['Description']]

# Train the LDA model
lda_model_SD = LdaModel(bow_corpus_SD, num_topics=3, id2word=dictionary_SD, passes=10)

# Print the topics
for idx, topic in lda_model_SD.print_topics(-1):
    print(f'Topic: {idx} \nWords: {topic}\n')
    
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Prepare the visualization
lda_vis_data_SD = gensimvis.prepare(lda_model_SD, bow_corpus_SD, dictionary_SD)

# Display the visualization
pyLDAvis.display(lda_vis_data_SD)
# Out:
# Topic: 0
# Words: 0.022*"software" + 0.012*"development" + 0.011*"team" + 0.008*"code" + 0.007*"work" + 0.007*"design" + 0.006*"solutions" + 0.006*"ensure" + 0.006*"description" + 0.006*"develop"
#
# Topic: 1
# Words: 0.007*"software" + 0.006*"work" + 0.006*"team" + 0.005*"de" + 0.005*"description" + 0.005*"starling" + 0.005*"new" + 0.004*"features" + 0.004*"en" + 0.004*"working"
#
# Topic: 2
# Words: 0.017*"software" + 0.012*"work" + 0.010*"team" + 0.010*"development" + 0.008*"design" + 0.007*"description" + 0.006*"new" + 0.006*"clients" + 0.006*"systems" + 0.005*"product"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2127559615688161094950740" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2127559615688161094950740_data = {"mdsDat": {"x": [-0.07950897952380002, -0.04502429166114288, 0.12453327118494295], "y": [0.05706938075165678, -0.06867617521544891, 0.011606794463792033], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [54.79905976611425, 28.839381237604734, 16.36155899628103]}, "tinfo": {"Term": ["de", "starling", "work", "en", "new", "features", "everyone", "development", "engine", "clients", "around_world", "xplore", "building", "app", "like", "make", "everything", "together", "platform", "deliver", "developer", "banking", "solutions", "customers", "one", "developers", "best", "things", "leading", "la", "typedb", "blockchain", "functional", "effectively", "coordinate", "sales", "database", "functionality", "futurex", "plans", "timely", "futurexs", "documenting", "seeking_talented", "development_life_cycle", "limited", "common", "delivery", "vaticle", "appropriate", "ensuring", "expand", "game", "api", "community", "stay_uptodate", "concepts", "icarda", "cgiar", "payment", "highquality", "develop", "members", "process", "requirements", "c", "clean", "manager", "ensure", "technical", "management", "code", "opportunities", "software", "project", "development", "role", "applications", "solutions", "maintain", "team", "responsible", "support", "quality", "design", "technologies", "responsibilities", "developer", "developing", "description", "looking", "work", "provide", "using", "projects", "working", "product", "teams", "systems", "technology", "xplore", "smartlogic", "ryanair", "space", "labs", "basis", "energy", "custom", "andor_phoenixelixir", "ruby_rails", "consultancy", "emergency", "electromechanical", "least", "smartnews", "occasionally", "weekly", "micro", "startups", "record", "coaching", "integrations", "sdks", "developmentrisk", "mitigation", "solutioning", "redesigns", "corresponding", "nan", "impacting", "since", "initiatives", "successful", "assigned", "leading", "clients", "operations", "work", "professionals", "new", "one", "developers", "software", "product", "systems", "design", "development", "team", "description", "engineering", "best", "developer", "build", "services", "information", "products", "join", "experience", "solutions", "working", "business", "data", "company", "code", "projects", "responsibilities", "us", "role", "de", "starling", "en", "la", "desarrollo", "el", "bank", "fabulous", "citizens", "con", "ponyai", "changing", "equipos", "bajo", "es", "clave", "proyectos", "hugosave", "banks", "caring", "greatness", "technologists", "worldclass", "engine", "experiencia", "del", "las", "disruptive", "five", "winning", "banking", "everything", "everyone", "london", "autonomous", "around_world", "together", "features", "like", "app", "youre", "things", "building", "make", "deliver", "platform", "customers", "new", "work", "description", "software", "working", "team", "help", "across", "us", "people", "technology", "teams", "best", "looking"], "Freq": [11.0, 10.0, 104.0, 8.0, 46.0, 21.0, 10.0, 117.0, 8.0, 37.0, 11.0, 10.0, 24.0, 13.0, 14.0, 18.0, 7.0, 8.0, 24.0, 22.0, 48.0, 6.0, 59.0, 23.0, 23.0, 31.0, 28.0, 9.0, 14.0, 4.0, 15.149159298198311, 14.274360873352878, 10.785707019332726, 9.916970296731053, 9.043099124018072, 9.02901951151847, 9.023070636869232, 9.005504492786772, 8.172616751943396, 8.162147622468524, 9.783210005182218, 7.297634783616732, 7.292701357318198, 7.259041389805748, 6.411051834347606, 6.410686336506194, 6.408834613203129, 17.680629130237243, 6.404893990280343, 6.402766951755431, 11.975895915213952, 5.545900566114131, 5.545648293147504, 5.542215791680333, 5.541059706116737, 5.540025188313437, 5.536341605720426, 5.534578873196139, 5.533807354926551, 5.531505910366444, 13.406279663184174, 38.36835202266361, 13.099742980076318, 18.594588265108374, 30.061396539109314, 14.175256928214601, 9.936094574002663, 16.055802119757008, 41.644232897426946, 36.687923255778344, 25.656548451461745, 54.73164906552139, 16.06602493546919, 153.2642924734933, 34.506981744863 ...

# %% [markdown]
# **UI/UX**

# %%
data_uiux
# Out:
#     Category                                        Description
# 315    UI/UX  Description\nJob Title: UI/UX Designer\nRequir...
# 316    UI/UX  Description\nThe UX Designer will be focused o...
# 317    UI/UX  Description\nWe are seeking a dynamic UI/UX de...
# 318    UI/UX  Description\nWe are looking for a UI/UX Design...
# 319    UI/UX  Description\nJob Title: UI/UX Designer\nRequir...
# 320    UI/UX  Description\nThe UX Designer will be focused o...
# 321    UI/UX  Description\nWe are seeking a dynamic UI/UX de...
# 322    UI/UX  Description\nWe are looking for a UI/UX Design...
# 323    UI/UX  Description\nRemote – Full-Time\nClay is a glo...
# 324    UI/UX  Description\nRemote – Full-Time\nClay is a glo...

# %%
# Preprocess the text data
def preprocess_text(text):
    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# Apply preprocessing to the Description column
data_uiux['Description'] = data_uiux['Description'].apply(preprocess_text)

# %%
# Create bigrams and trigrams
bigram = Phrases(data_uiux['Description'], min_count=5, threshold=100)
trigram = Phrases(bigram[data_uiux['Description']], min_count=5, threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
data_uiux['Description'] = [bigram_mod[doc] for doc in data_uiux['Description']]
data_uiux['Description'] = [trigram_mod[bigram_mod[doc]] for doc in data_uiux['Description']]

# Create a dictionary representation of the documents
dictionary_uiux = corpora.Dictionary(data_uiux['Description'])

# Convert the documents into a bag-of-words format
bow_corpus_uiux = [dictionary_uiux.doc2bow(doc) for doc in data_uiux['Description']]

# Train the LDA model
lda_model_uiux = LdaModel(bow_corpus_uiux, num_topics=3, id2word=dictionary_uiux, passes=10)

# Print the topics
for idx, topic in lda_model_uiux.print_topics(-1):
    print(f'Topic: {idx} \nWords: {topic}\n')
    
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Prepare the visualization
lda_vis_data_uiux= gensimvis.prepare(lda_model_uiux, bow_corpus_uiux, dictionary_uiux)

# Display the visualization
pyLDAvis.display(lda_vis_data_uiux)
# Out:
# Topic: 0
# Words: 0.039*"user" + 0.033*"design" + 0.018*"web" + 0.015*"uiux" + 0.015*"experience" + 0.012*"team" + 0.012*"marketing" + 0.009*"designer" + 0.009*"collaborate" + 0.009*"understand"
#
# Topic: 1
# Words: 0.042*"design" + 0.034*"user" + 0.033*"experience" + 0.017*"uiux" + 0.017*"interface" + 0.017*"successful" + 0.010*"work" + 0.010*"designer" + 0.009*"best" + 0.009*"ux"
#
# Topic: 2
# Words: 0.033*"design" + 0.024*"user" + 0.015*"designs" + 0.015*"ux" + 0.012*"team" + 0.012*"product" + 0.012*"designer" + 0.012*"work" + 0.009*"uiux" + 0.009*"software"
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2127559615703846727908000" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el2127559615703846727908000_data = {"mdsDat": {"x": [-0.11576384778975114, 0.1101739765616803, 0.005589871228070712], "y": [-0.03387779879084053, -0.03930995883448813, 0.07318775762532871], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [44.603112942467114, 44.59676802770057, 10.800119029832311]}, "tinfo": {"Term": ["experience", "design", "user", "interface", "successful", "ux", "web", "uiux", "digital", "software", "usability", "responsible", "problems", "elements", "creative", "date", "online", "delivering", "various", "candidate", "ui", "includes", "applications", "wireframe", "webmobile", "projects", "meet", "portfolio", "marketing", "product", "web", "marketing", "manager", "testing", "translate", "video", "visually", "designers", "senior", "thinking", "remote", "improve", "clay", "working", "interfaces", "research", "intuitive", "skills", "ways", "worldclass", "personas", "information", "highfidelity", "feasibility", "fastmoving", "preferences", "fostering", "improvement", "art", "wants", "digital", "understand", "innovative", "user", "responsible", "usability", "design", "uiux", "experience", "collaborate", "team", "designer", "stakeholders", "develop", "gather", "us", "teams", "create", "role", "requirements", "appealing", "conduct", "clients", "work", "looking", "description", "products", "industry", "product", "rapidly", "graphic", "like", "designing", "standards", "troubleshoot", "eg", "leaders", "ability", "mockups", "deliverables", "identify", "based", "images", "illustrate", "ux", "performance", "problem", "routine", "specs", "strategic", "focused", "upon", "agile", "changing", "qualified", "follow", "take", "errors", "designs", "software", "iterate", "responsibilities", "elements", "problems", "work", "practices", "best", "design", "requirements", "create", "designer", "team", "user", "uiux", "experience", "description", "clients", "interface", "looking", "role", "adaptive", "passion", "staying", "exceptional", "improved", "seeking", "usefulness", "assets", "visuals", "optimized", "dynamic", "evidence", "want", "successful", "interface", "creative", "online", "date", "delivering", "various", "candidate", "ui", "projects", "applications", "includes", "wireframe", "portfolio", "webmobile", "meet", "experience", "design", "user", "uiux", "emerging", "technology", "trends", "work", "ensure", "best", "designer", "practices", "solutions", "digital", "ux", "description", "usability", "problems", "role", "responsible", "tools", "also", "software", "professional"], "Freq": [16.0, 42.0, 40.0, 6.0, 4.0, 10.0, 10.0, 16.0, 6.0, 6.0, 5.0, 5.0, 5.0, 5.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 7.0, 7.0, 10.215904925160112, 6.899653225278679, 3.591226117149004, 3.5912201266819817, 3.5886358912994853, 3.5875167157866263, 3.5872463634053493, 3.586636377589404, 3.5880808615070947, 3.586024308132756, 3.5853354044251664, 3.58506244749301, 3.5833913676488156, 3.583112680704725, 3.581148849341691, 3.580946996648541, 3.580037227026382, 3.5805787131542, 3.578386202223959, 3.57978771105214, 1.9361246716893945, 1.9352173763905711, 1.9347917927768845, 1.9346757600352091, 1.9345694943593315, 1.9343013558463018, 1.9342772637506678, 1.9344890137371593, 1.9341597985060088, 1.9339945397527138, 5.234273180228782, 5.247520967821534, 5.233049041315485, 21.89175229838975, 3.5888169075856005, 3.585712543392497, 18.55070735777756, 8.60420154827267, 8.570917992585391, 5.2576729862390845, 6.9144100896509295, 5.288063406809576, 3.6128037793641097, 3.61149290890653, 3.6076863577963527, 3.607076371980408, 3.6061194599873327, 3.6305639513553447, 3.6204158397641133, 3.621915279705358, 3.604868754655066, 3.6013955860574463, 3.6101908939219407, 3.6130189152667445, 3.6073602680262575, 3.604192873701874, 3.5982130853379624, 3.594166655091796, 6.920643721401735, 5.255777145172415, 5.264521462035158, 5.255538081414001, 3.6045312135577845, 3.6032970924781327, 3.602105679956629, 3.6056369485449546, 3.5989322257518106, 3 ...
